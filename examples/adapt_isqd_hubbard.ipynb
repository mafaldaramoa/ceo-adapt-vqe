# %%
from typing import List
from copy import deepcopy

import collections
import matplotlib.pyplot as plt; plt.rcParams.update({"font.family": "serif"})

import pyscf
import pyscf.cc
import pyscf.mcscf

# To get molecular geometries.
import openfermion as of
from openfermion import MolecularData
from openfermionpyscf import run_pyscf

import qiskit
from qiskit import QuantumCircuit, QuantumRegister
from qiskit.primitives import BitArray
from qiskit_aer import AerSimulator  # For MPS Simulator.

import ffsim

# To run on hardware.
import qiskit_ibm_runtime
from qiskit_ibm_runtime import SamplerV2 as Sampler

from functools import partial

import numpy as np

from qiskit_addon_sqd.fermion import SCIResult, diagonalize_fermionic_hamiltonian, solve_sci_batch

from adaptvqe.pools import DVG_CEO, FullPauliPool
from adaptvqe.hamiltonians import HubbardHamiltonian
from adaptvqe.algorithms.adapt_vqe import LinAlgAdapt, TensorNetAdapt

# %%
ibm_computer: str = "ibm_fez"

service = qiskit_ibm_runtime.QiskitRuntimeService(channel="local")
computer = service.backend()
sampler = Sampler(computer)
# Out:
# /Users/benjamindalfavero/.venv/adapt/lib/python3.13/site-packages/qiskit_ibm_runtime/fake_provider/backends/nighthawk/fake_nighthawk.py:76: UserWarning: Properties of fake_nighthawk are not intended to represent typical nighthawk error values.
#   warnings.warn(

# %%
l = 2
sys_size = l * l
t = 1.0
u = 4.0
hamiltonian = HubbardHamiltonian(l, l, t, u, False, True)

exact_energy = hamiltonian.ground_energy
print(f"Ground state energy = {exact_energy}")
# Out:
# Ground state energy = -6.102748483462062

# %%
def neel_circuit(nq):
    circuit = QuantumCircuit(nq)
    for i in range(nq):
        if i % 2 == 0:
            circuit.x(i)
        else:
            circuit.id(i)
    return circuit

# %%
pool = FullPauliPool(n=sys_size)

max_mpo_bond = 200
adapt_mps_bond = 10
my_adapt = TensorNetAdapt(
    pool=pool,
    custom_hamiltonian=hamiltonian,
    max_adapt_iter=1,
    recycle_hessian=True,
    tetris=True,
    verbose=True,
    threshold=0.1,
    max_mpo_bond=max_mpo_bond,
    max_mps_bond=adapt_mps_bond
)

my_adapt.initialize()
nq = my_adapt.n

circuits = []
adapt_energies = []
for i in range(6):
    print(f"On iteration {i}.")
    my_adapt.run_iteration()
    data = my_adapt.data
    ansatz_circuit = pool.get_circuit(my_adapt.indices, my_adapt.coefficients)
    print("coefficients:", my_adapt.coefficients)
    print("indices:", my_adapt.indices)
    # Prepare the HF reference state, then add the Ansatz circuit.
    q = QuantumRegister(nq)
    circuit = QuantumCircuit(q)
    # circuit.append(ffsim.qiskit.PrepareHartreeFockJW(num_orbitals, nelec), q)
    circuit = circuit.compose(neel_circuit(nq))
    circuit = circuit.compose(ansatz_circuit)
    circuit.measure_all()
    circuits.append(circuit)
    adapt_energies.append(my_adapt.energy)
# Out:
# tensor-net-adapt prepared with the following settings:
# > Pool: full_pauli_pool
# > Custom Hamiltonian: HH_2_2_1.0_4.0
# > Orbital Optimization: False
# > Selection method: gradient
# > Convergence criterion: total_g_norm
# > Recycling Hessian: True
# > Tetris: True (progressive optimization: False)
# > Convergence threshold (gradient norm):  0.1
# > Maximum number of iterations:  1
# > candidates per iteration:  1
#
# Initial energy: -4.0000000000000036
# On iteration 0.
#
# *** ADAPT-VQE Iteration 1 ***
#
# Creating list of up to 255 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 38: -2.0000000000000036
# Operator 39: -2.0000000000000036
# Operator 54: 2.0000000000000036
# Operator 55: 2.0000000000000036
# Operator 98: 2.0000000000000036
# Operator 99: 2.0000000000000036
# Operator 114: -2.0000000000000036
# Operator 115: -2.0000000000000036
# Operator 137: 2.0000000000000013
# Operator 141: -2.0000000000000013
# Operator 152: -2.0000000000000013
# Operator 156: 2.0000000000000013
# Operator 201: 2.0000000000000013
# Operator 205: -2.0000000000000013
# Operator 216: -2.0000000000000013
# Operator 220: 2.0000000000000013
# Total gradient norm: 8.00000000000001
# Operators under consideration (16):
# [38, 39, 54, 55, 98, 99, 114, 115, 137, 141, 152, 156, 201, 205, 216, 220]
# Corresponding gradients (ordered by magnitude):
# [np.float64(-2.0000000000000036), np.float64(-2.0000000000000036), np.float64(2.0000000000000036), np.float64(2.0000000000000036), np.float64(2.0000000000000036), np.float64(2.0000000000000036), np.float64(-2.0000000000000036), np.float64(-2.0000000000000036), np.float64(2.0000000000000013), np.float64(-2.0000000000000013), np.float64(-2.0000000000000013), np.float64(2.0000000000000013), np.float64(2.0000000000000013), np.float64(-2.0000000000000013), np.float64(-2.0000000000000013), np.float64(2.0000000000000013)]
# Operator(s) added to ansatz: [38]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -4.0000000000000036
# Optimizing energy with indices [38]...
# Starting point: [np.float64(0.0)]
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2492: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   opt_result = minimize_bfgs(
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2507: UserWarning: Optimizer did not succeed. Message: Desired error not necessarily achieved due to precision loss.
#   warn(f"Optimizer did not succeed. Message: {opt_result.message}")
#          Current function value: -4.236068
#          Iterations: 6
#          Function evaluations: 35
#          Gradient evaluations: 24
#
# Current energy: -4.236067977499787
# (change of -0.2360679774997836)
# Current ansatz: [38]
# coefficients: [np.float64(0.23182377058830256)]
# indices: [38]
# On iteration 1.
#
# *** ADAPT-VQE Iteration 2 ***
#
# Creating list of up to 255 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 4: 0.8944270696722953
# Operator 21: 0.8944270696722953
# Operator 38: -3.0331905002956017e-07
# Operator 39: -3.0331905002956017e-07
# Operator 54: 3.0331905002956017e-07
# Operator 55: 3.0331905002956017e-07
# Operator 64: -0.8944270696722953
# Operator 81: -0.8944270696722953
# Operator 98: 3.0331905002956017e-07
# Operator 99: 3.0331905002956017e-07
# Operator 114: -3.0331905002956017e-07
# Operator 115: -3.0331905002956017e-07
# Operator 137: 1.7888544426636388
# Operator 141: -2.0000000000000018
# Operator 152: -1.7888544426636388
# Operator 156: 2.0000000000000018
# Operator 201: 2.0000000000000018
# Operator 205: -1.7888544426636388
# Operator 216: -2.0000000000000018
# Operator 220: 1.7888544426636388
# Total gradient norm: 5.656854249492451
# Operators under consideration (20):
# [141, 156, 201, 216, 137, 152, 205, 220, 4, 21, 64, 81, 38, 39, 54, 55, 98, 99, 114, 115]
# Corresponding gradients (ordered by magnitude):
# [np.float64(-2.0000000000000018), np.float64(2.0000000000000018), np.float64(2.0000000000000018), np.float64(-2.0000000000000018), np.float64(1.7888544426636388), np.float64(-1.7888544426636388), np.float64(-1.7888544426636388), np.float64(1.7888544426636388), np.float64(0.8944270696722953), np.float64(0.8944270696722953), np.float64(-0.8944270696722953), np.float64(-0.8944270696722953), np.float64(-3.0331905002956017e-07), np.float64(-3.0331905002956017e-07), np.float64(3.0331905002956017e-07), np.float64(3.0331905002956017e-07), np.float64(3.0331905002956017e-07), np.float64(3.0331905002956017e-07), np.float64(-3.0331905002956017e-07), np.float64(-3.0331905002956017e-07)]
# Operator(s) added to ansatz: [141]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -4.236067977499787
# Optimizing energy with indices [38, 141]...
# Starting point: [np.float64(0.23182377058830256), np.float64(0.0)]
#          Current function value: -4.500000
#          Iterations: 7
#          Function evaluations: 43
#          Gradient evaluations: 31
#
# Current energy: -4.500000000000015
# (change of -0.26393202250022796)
# Current ansatz: [38, 141]
# coefficients: [np.float64(0.2617993846061695), np.float64(0.2617993923551915)]
# indices: [38, 141]
# On iteration 2.
#
# *** ADAPT-VQE Iteration 3 ***
#
# Creating list of up to 255 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: -0.8660254206455485
# Operator 4: 0.8660253896494595
# Operator 16: 0.8660254206455485
# Operator 21: 0.8660253896494595
# Operator 38: 0.49999998023927655
# Operator 39: -3.4655926961502104e-08
# Operator 54: 3.4655926961502104e-08
# Operator 55: -0.49999998023927655
# Operator 64: -0.8660253896494595
# Operator 69: -0.8660254206455485
# Operator 81: -0.8660253896494595
# Operator 84: 0.8660254206455485
# Operator 98: -0.49999998023927655
# Operator 99: 3.4655926961502104e-08
# Operator 114: -3.4655926961502104e-08
# Operator 115: 0.49999998023927655
# Operator 137: -0.5000000339260768
# Operator 141: 4.2834294250448934e-08
# Operator 152: 0.5000000339260768
# Operator 156: -4.2834294250448934e-08
# Operator 201: -4.2834294250448934e-08
# Operator 205: 0.5000000339260768
# Operator 216: 4.2834294250448934e-08
# Operator 220: -0.5000000339260768
# Total gradient norm: 2.828427138101426
# Operators under consideration (24):
# [1, 16, 69, 84, 4, 21, 64, 81, 137, 152, 205, 220, 38, 55, 98, 115, 141, 156, 201, 216, 39, 54, 99, 114]
# Corresponding gradients (ordered by magnitude):
# [np.float64(-0.8660254206455485), np.float64(0.8660254206455485), np.float64(-0.8660254206455485), np.float64(0.8660254206455485), np.float64(0.8660253896494595), np.float64(0.8660253896494595), np.float64(-0.8660253896494595), np.float64(-0.8660253896494595), np.float64(-0.5000000339260768), np.float64(0.5000000339260768), np.float64(0.5000000339260768), np.float64(-0.5000000339260768), np.float64(0.49999998023927655), np.float64(-0.49999998023927655), np.float64(-0.49999998023927655), np.float64(0.49999998023927655), np.float64(4.2834294250448934e-08), np.float64(-4.2834294250448934e-08), np.float64(-4.2834294250448934e-08), np.float64(4.2834294250448934e-08), np.float64(-3.4655926961502104e-08), np.float64(3.4655926961502104e-08), np.float64(3.4655926961502104e-08), np.float64(-3.4655926961502104e-08)]
# Operator(s) added to ansatz: [1]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -4.500000000000015
# Optimizing energy with indices [38, 141, 1]...
# Starting point: [np.float64(0.2617993846061695), np.float64(0.2617993923551915), np.float64(0.0)]
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2492: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   opt_result = minimize_bfgs(
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2507: UserWarning: Optimizer did not succeed. Message: Desired error not necessarily achieved due to precision loss.
#   warn(f"Optimizer did not succeed. Message: {opt_result.message}")
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2492: OptimizeWarning: Desired error not necessarily achieved due to precision loss.
#   opt_result = minimize_bfgs(
# /Users/benjamindalfavero/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:2507: UserWarning: Optimizer did not succeed. Message: Desired error not necessarily achieved due to precision loss.
#   warn(f"Optimizer did not succeed. Message: {opt_result.message}")
#          Current function value: -4.828427
#          Iterations: 12
#          Function evaluations: 44
#          Gradient evaluations: 34
#
# Current energy: -4.828427124732341
# (change of -0.32842712473232627)
# Current ansatz: [38, 141, 1]
# coefficients: [np.float64(1.6844781307100838e-06), np.float64(0.3926992094468564), np.float64(0.7853983713914718)]
# indices: [38, 141, 1]
# On iteration 3.
#
# *** ADAPT-VQE Iteration 4 ***
#
# Creating list of up to 255 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 5.882960874004084e-07
# Operator 16: -5.882960874004084e-07
# Operator 38: 1.4453050078411245e-06
# Operator 39: 8.319760933517273e-07
# Operator 54: -8.319760933517273e-07
# Operator 55: -1.4453050078411245e-06
# Operator 69: 5.882960874004084e-07
# Operator 84: -5.882960874004084e-07
# Operator 98: -1.4453050078411245e-06
# Operator 99: -8.319760933517273e-07
# Operator 114: 8.319760933517273e-07
# Operator 115: 1.4453050078411245e-06
# Operator 137: -1.4453052529228572e-06
# Operator 141: -5.882963884928927e-07
# Operator 152: 1.4453052529228572e-06
# Operator 156: 5.882963884928927e-07
# Operator 201: 5.882963884928927e-07
# Operator 205: 1.4453052529228572e-06
# Operator 216: -5.882963884928927e-07
# Operator 220: -1.4453052529228572e-06
# Total gradient norm: 4.716856150823448e-06
# coefficients: [np.float64(1.6844781307100838e-06), np.float64(0.3926992094468564), np.float64(0.7853983713914718)]
# indices: [38, 141, 1]
# On iteration 4.
#
# *** ADAPT-VQE Iteration 4 ***
#
# Creating list of up to 255 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 5.882960874004084e-07
# Operator 16: -5.882960874004084e-07
# Operator 38: 1.4453050078411245e-06
# Operator 39: 8.319760933517273e-07
# Operator 54: -8.319760933517273e-07
# Operator 55: -1.4453050078411245e-06
# Operator 69: 5.882960874004084e-07
# Operator 84: -5.882960874004084e-07
# Operator 98: -1.4453050078411245e-06
# Operator 99: -8.319760933517273e-07
# Operator 114: 8.319760933517273e-07
# Operator 115: 1.4453050078411245e-06
# Operator 137: -1.4453052529228572e-06
# Operator 141: -5.882963884928927e-07
# Operator 152: 1.4453052529228572e-06
# Operator 156: 5.882963884928927e-07
# Operator 201: 5.882963884928927e-07
# Operator 205: 1.4453052529228572e-06
# Operator 216: -5.882963884928927e-07
# Operator 220: -1.4453052529228572e-06
# Total gradient norm: 4.716856150823448e-06
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 24
#      22 for i in range(6):
#      23     print(f"On iteration {i}.")
# ---> 24     my_adapt.run_iteration()
#      25     data = my_adapt.data
#      26     ansatz_circuit = pool.get_circuit(my_adapt.indices, my_adapt.coefficients)
#
# File ~/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:1236, in AdaptVQE.run_iteration(self)
#    1231 """
#    1232 Run one iteration of the ADAPT-VQE algorithm.
#    1233 """
#    1235 # Screen viable candidates and calculate current total gradient norm
# -> 1236 finished, viable_candidates, viable_gradients, total_norm, prep_norm = self.start_iteration()
#    1238 if finished:
#    1239     # We have converged; do not complete the iteration
#    1240     return finished
#
# File ~/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:1376, in AdaptVQE.start_iteration(self)
#    1373     prep_norm = None
#    1375 # Check if we've reached a termination condition
# -> 1376 finished = self.probe_termination(total_norm, max_norm)
#    1378 if finished:
#    1379     return finished, viable_candidates, viable_gradients, total_norm, prep_norm
#
# File ~/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:1492, in AdaptVQE.probe_termination(self, total_norm, max_norm)
#    1489 finished = False
#    1491 if total_norm < self.threshold and self.convergence_criterion == "total_g_norm":
# -> 1492     self.converged()
#    1493     finished = True
#    1495 if max_norm < self.threshold and self.convergence_criterion == "max_g":
#
# File ~/Documents/phd/wellcome/ceo-adapt-vqe/adaptvqe/algorithms/adapt_vqe.py:1507, in AdaptVQE.converged(self)
#    1502 """
#    1503 To call when convergence is reached. Updates file name to include the total number of iterations executed.
#    1504 """
#    1506 # Update iteration number on file_name - we didn't reach the maximum
# -> 1507 pre_it, post_it = self.file_name.split(str(self.max_adapt_iter) + "i")
#    1508 self.file_name = "".join(
#    1509     [pre_it, str(self.data.iteration_counter) + "i", post_it]
#    1510 )
#    1511 self.data.close(True, self.file_name)
#
# ValueError: not enough values to unpack (expected 2, got 1)
