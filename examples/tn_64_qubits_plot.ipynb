# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 32 qubits with XXZ

# %%
f = h5py.File("../data/xxz_32_qubits.hdf5", "r")
dmrg_energy = f["dmrg_energy"][()]
adapt_energies = f["adapt_energies"][:]
adapt_times = f["adapt_times"][:]
f.close()

# %%
fig, ax = plt.subplots(2, 1, sharex=True)
ax[0].plot(range(1, len(adapt_energies) + 1), adapt_energies, '.', label="ADAPT")
ax[0].hlines(dmrg_energy, 1, len(adapt_energies), color='k', label="DMRG")
ax[0].legend()
ax[0].set_ylabel("Energy")
ax[1].plot(range(1, len(adapt_times) + 1), adapt_times)
ax[1].set_ylabel("Time (ns)")
ax[1].set_xlabel("Iteration")
# Out:
# /Users/benjamindalfavero/.venv/adapt/lib/python3.13/site-packages/numpy/ma/core.py:3463: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data[indx] = dval
# Text(0.5, 0, 'Iteration')
